# %% [markdown]
# # My Lane
#
# I selected the Ranking Prediction lane.
#
# The goal is to understand whether available SEO metrics can help identify pages that are more likely to achieve strong search rankings.
#
# This is useful because higher rankings can improve visibility, clicks, and organic traffic.

# %% [markdown]
# # Research Question
#
# Question:
# Can we predict whether a page is likely to achieve a strong search ranking based on available SEO metrics?
#
# Decision:
# Which pages should be prioritized for SEO improvements?
#
# Action:
# SEO teams can focus optimization efforts on pages that have the highest potential to improve rankings.
#
# Cost of Wrong Recommendation:
# If recommendations are incorrect, resources may be spent on low-potential pages while valuable opportunities are missed.

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

print("\nColumn Names:")
print(df.columns.tolist())
# Out:
# Rows: 30000
# Columns: 44
#
# Column Names:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']

# %% [markdown]
# # Quick Look at the Data
#
# The dataset contains 30,000 records and 44 columns.
#
# The average search position is 16.34, the average CTR is 0.5107, and the average search volume is 158.88.
#
# The dataset includes ranking-related variables such as impressions, clicks, CTR, search volume, engagement metrics, content age, and average position. These features suggest that the data may contain useful signals for predicting ranking performance.

# %% [markdown]
# # Careful Words
#
# This project aims to identify patterns associated with search ranking performance.
#
# The analysis cannot prove that a specific factor directly causes ranking improvements. Search rankings are influenced by many factors that may not be captured in the dataset.
#
# Any model developed in this project should be treated as a decision-support tool rather than a guarantee of future ranking outcomes.

# %% [markdown]
# # Self Check
#
# - Selected a lane ✓
# - Defined a research question ✓
# - Identified the decision ✓
# - Identified the action ✓
# - Explained the cost of a wrong recommendation ✓
# - Included real numbers from the dataset ✓
# - Explained limitations and uncertainty ✓

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print("Average Position:", round(df["avg_position"].mean(), 2))
print("Average CTR:", round(df["ctr"].mean(), 4))
print("Average Search Volume:", round(df["search_volume"].mean(), 2))
# Out:
# Average Position: 16.34
# Average CTR: 0.5107
# Average Search Volume: 158.88
